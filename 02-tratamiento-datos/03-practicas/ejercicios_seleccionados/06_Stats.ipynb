# %% [markdown]
# # Stats
#
# ### Dataset: US Baby Names

# %% [markdown]
# ### Ejercicio 1: Import
# Import pandas, numpy

# %%
# Pista: import pandas as pd; import numpy as np

# %%
assert 'pd' in dir()
print('✓ OK')

# %% [markdown]
# ### Ejercicio 2: Load data
# https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv

# %%
# Pista: pd.read_csv()
baby_names = None

# %%
assert baby_names.shape[0] > 0
print('✓ Cargado')

# %% [markdown]
# ### Ejercicio 3: Preview
# First rows

# %%
# Pista: .head()

# %%
print('OK')
print('✓ OK')

# %% [markdown]
# ### Ejercicio 4: Drop cols
# Delete 'Unnamed: 0' and 'Id'

# %%
# Pista: .drop(['Unnamed: 0', 'Id'], axis=1)
bn_clean = None

# %%
assert bn_clean is not None
print('✓ Limpio')

# %% [markdown]
# ### Ejercicio 5: Gender count
# More male or female names?

# %%
# Pista: .groupby('Gender').size()
gender_count = None

# %%
assert gender_count is not None
print('✓ OK')

# %% [markdown]
# ### Ejercicio 6: Group by name
# Groupby name

# %%
# Pista: .groupby('Name')
by_name = None

# %%
assert by_name is not None
print('✓ OK')

# %% [markdown]
# ### Ejercicio 7: Unique names
# How many different names?

# %%
# Pista: .nunique() or .groupby().ngroups
num_names = None

# %%
assert num_names > 0
print('✓ OK')

# %% [markdown]
# ### Ejercicio 8: Most common
# Name with most occurrences

# %%
# Pista: .groupby('Name').Count.sum().idxmax()
most_common = None

# %%
assert most_common is not None
print('✓ OK')

# %% [markdown]
# ### Ejercicio 9: Least common
# How many with least?

# %%
# Pista: ...min()...
least_count = None

# %%
assert least_count > 0
print('✓ OK')

# %% [markdown]
# ### Ejercicio 10: Median
# Median name occurrence

# %%
# Pista: .groupby('Name').Count.sum().median()
med = None

# %%
assert med > 0
print('✓ OK')

# %% [markdown]
# ### Ejercicio 11: Std
# Standard deviation

# %%
# Pista: .std()
std_val = None

# %%
assert std_val > 0
print('✓ OK')

# %% [markdown]
# ### Ejercicio 12: Describe
# Summary stats

# %%
# Pista: .describe()
summary = None

# %%
assert summary is not None
print('✓ OK')

# %% [markdown]
# ### Ejercicio 13: Top 10
# Top 10 names

# %%
# Pista: .groupby('Name').Count.sum().nlargest(10)
top10 = None

# %%
assert len(top10) == 10
print('✓ OK')

# %% [markdown]
# ### Ejercicio 14: Percentiles
# 25th, 50th, 75th

# %%
# Pista: .quantile([.25, .5, .75])
perc = None

# %%
assert perc is not None
print('✓ OK')

# %% [markdown]
# ### Ejercicio 15: Trend
# Names trend over time

# %%
# Pista: .groupby(['Year', 'Name']).Count.sum()
trend = None

# %%
assert trend is not None
print('✓ OK')

# %% [markdown]
# ## ¡Completado! 🎉
