# %% [markdown]
# # 16 - Polars: selección, joins y groupby (práctico)

# %% [markdown]
# Operaciones comunes y pipelines lazy.

# %%
import numpy as np, pandas as pd
try:
    import polars as pl
    HAS_POLARS = True
    print("✅ Polars importado:", pl.__version__)
except:
    HAS_POLARS = False
    print("⚠️ Polars no disponible")
# Out:
# ✅ Polars importado: 1.34.0

# %% [markdown]
# ### Explicación
# Inicialización de entorno: se intenta importar Polars y se marca bandera `HAS_POLARS`. Punto de partida para añadir luego ejemplos de selección, joins y pipelines lazy.
