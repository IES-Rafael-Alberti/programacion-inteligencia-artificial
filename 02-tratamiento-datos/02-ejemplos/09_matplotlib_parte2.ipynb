# %% [markdown]
# # Matplotlib – Mega Chuleta (Parte 2)
#
# 💬 Esta parte continúa la **Mega Chuleta de Matplotlib (Parte 1)** y se centra en la **personalización, anotaciones, estilos y presentación visual** de gráficos.

# %% [markdown]
# ## Personalización visual avanzada
# 💡 **Idea clave:** Personaliza colores, estilos, transparencia y fuentes.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.style.use('seaborn-v0_8-whitegrid')  # Estilo base

tips = sns.load_dataset("tips")

plt.figure(figsize=(6,4))
plt.scatter(tips["total_bill"], tips["tip"], c=tips["size"], cmap="cool", alpha=0.7, edgecolors="black")
plt.title("Relación entre total y propina")
plt.xlabel("Total de la cuenta ($)")
plt.ylabel("Propina ($)")
plt.colorbar(label="Tamaño de grupo")
plt.show()

# %% [markdown]
# ✅ **Consejo:** Usa `alpha` para transparencia y `cmap` para paletas automáticas.
#
# 🧩 **Ejercicio:** Cambia el estilo a `ggplot` o `dark_background` con `plt.style.use('ggplot')` y observa las diferencias.

# %% [markdown]
# ## Anotaciones y texto
# 💡 **Idea clave:** Usa `plt.text()` y `plt.annotate()` para resaltar información.

# %%
plt.figure(figsize=(6,4))
plt.scatter(tips["total_bill"], tips["tip"], alpha=0.6)
plt.title("Ejemplo de anotaciones")
plt.xlabel("Total de la cuenta ($)")
plt.ylabel("Propina ($)")

plt.text(45, 2, "Valor alto", fontsize=10, color="red")
plt.annotate("Propina inusualmente alta",
             xy=(40, 8), xytext=(25, 10),
             arrowprops=dict(facecolor="black", shrink=0.05, width=1))

plt.show()

# %% [markdown]
# ✅ **Consejo:** Usa `xycoords='data'` o `'axes fraction'` para posicionar texto relativo.
#
# 🧩 **Ejercicio:** Marca el punto con mayor `total_bill` del dataset.

# %% [markdown]
# ## Leyendas y títulos
# 💡 **Idea clave:** Las leyendas ayudan a interpretar los datos; colócalas sin tapar información.

# %%
plt.figure(figsize=(6,4))
for day, df_day in tips.groupby("day"):
    plt.scatter(df_day["total_bill"], df_day["tip"], label=day, alpha=0.6)

plt.title("Propinas por día de la semana", fontsize=14, fontweight="bold")
plt.xlabel("Total ($)")
plt.ylabel("Propina ($)")
plt.legend(title="Día", loc="upper left", fontsize=9, title_fontsize=10, bbox_to_anchor=(1, 0.5))
plt.show()
# Out:
# /tmp/ipykernel_49976/23798154.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for day, df_day in tips.groupby("day"):

# %% [markdown]
# ✅ **Consejo:** Usa `bbox_to_anchor` para mover la leyenda fuera del gráfico.
#
# 🧩 **Ejercicio:** Coloca la leyenda fuera (`loc='center left', bbox_to_anchor=(1, 0.5)`).

# %% [markdown]
# ## Cuadrículas, líneas y fondos
# 💡 **Idea clave:** Usa cuadrículas y líneas para resaltar tendencias o referencias.

# %%
flights = sns.load_dataset("flights")
pivot = flights.pivot_table(values="passengers", index="month", columns="year")
print(flights.head())
print(pivot.head())
plt.figure(figsize=(8,4))
plt.plot(pivot[1949], label="1949", linestyle="--")
plt.plot(pivot[1960], label="1960", linestyle="-", linewidth=2)

plt.title("Comparación de pasajeros por año")
plt.xlabel("Mes")
plt.ylabel("Pasajeros")
plt.grid(True, linestyle="--", alpha=0.5)
plt.axhline(y=350, color="red", linestyle=":", label="Referencia")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_49976/690255584.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = flights.pivot_table(values="passengers", index="month", columns="year")
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
#
# year    1959   1960
# month
# Jan    360.0  417.0
# Feb    342.0  391.0
# Mar    406.0  419.0
# Apr    396.0  461.0
# May    420.0  472.0

# %% [markdown]
# ✅ **Consejo:** Usa `axhline`, `axvline`, `axhspan`, `axvspan` para marcar rangos o umbrales.
#
# 🧩 **Ejercicio:** Añade un fondo gris con `plt.gca().set_facecolor('whitesmoke')`.

# %% [markdown]
# ## Guardado y exportación profesional
# 💡 **Idea clave:** Usa `plt.savefig()` con DPI y márgenes controlados para resultados profesionales.

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=tips, x="day", y="total_bill", palette="pastel")
plt.title("Gasto medio por día")

plt.tight_layout()
plt.savefig("gasto_medio_dia.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# /tmp/ipykernel_49976/3762177993.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tips, x="day", y="total_bill", palette="pastel")

# %% [markdown]
# ✅ **Consejo:** Usa `bbox_inches='tight'` para evitar cortes y `dpi>=300` para calidad alta.
#
# 🧩 **Ejercicio:** Exporta también en PDF y SVG para comparar nitidez.

# %% [markdown]
# ## Bonus: Estilos globales y paletas corporativas
# 💡 **Idea clave:** Los estilos globales y las paletas personalizadas dan coherencia visual.

# %%
plt.style.use('seaborn-v0_8-darkgrid')
# plt.style.use('ggplot')
# plt.style.use('dark_background')

# %%
from matplotlib.colors import ListedColormap

colores_empresa = ["#003366", "#6699CC", "#FFCC00"]
cmap_empresa = ListedColormap(colores_empresa)

plt.figure(figsize=(6,3))
sns.barplot(data=tips, x="day", y="tip", palette=colores_empresa)
plt.title("Ejemplo con paleta corporativa")
plt.show()
# Out:
# /tmp/ipykernel_49976/4199690749.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tips, x="day", y="tip", palette=colores_empresa)
# /tmp/ipykernel_49976/4199690749.py:7: UserWarning:
# The palette list has fewer values (3) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(data=tips, x="day", y="tip", palette=colores_empresa)

# %% [markdown]
# ✅ **Consejo:** Si trabajas en entornos profesionales, adapta las paletas a los colores corporativos.

# %% [markdown]
# ---
# 📘 **Resumen rápido**
# - Personaliza con `style`, `alpha`, `linewidth`, `font`, `grid`.
# - Usa `annotate()` para destacar insights.
# - Controla leyendas y títulos con `loc`, `fontsize`, `bbox_to_anchor`.
# - Exporta con `savefig()` en alta calidad.
# - Aplica estilos y paletas corporativas para informes consistentes.
