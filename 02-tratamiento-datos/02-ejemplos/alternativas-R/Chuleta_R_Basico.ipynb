# %% [markdown]
# # Chuleta esencial de **R** (notebook didáctico)
#
# Autor: José Manuel Sánchez Álvarez
# Centro: IES Rafael Alberti — Curso 2025–2026
#
# Este notebook resume lo **básico de R** (variables, tipos, operadores, estructuras, control, funciones, E/S de datos y gráficos).
# Pensado para ejecutarse en **VS Code** y **JupyterLab** con **kernel R**.

# %% [markdown]
# ## 0. Preparación del entorno
#
# - Se cargará `tidyverse` para disponer de `dplyr`, `ggplot2`, `readr`, etc.
# - Los gráficos aparecerán **inline** en el notebook.

# %%
suppressPackageStartupMessages({
  if (!requireNamespace("tidyverse", quietly = TRUE)) {
    install.packages("tidyverse", repos = "https://cloud.r-project.org")
  }
  if (!requireNamespace("ggcorrplot", quietly = TRUE)) {
    install.packages("ggcorrplot", repos = "https://cloud.r-project.org")
  }
  library(tidyverse)
  library(ggcorrplot)
})
options(repr.plot.width = 7, repr.plot.height = 4)  # Tamaño de gráficos inline (si está disponible)
sessionInfo()
# Out:
# R version 4.5.2 (2025-10-31)
# Platform: x86_64-pc-linux-gnu
# Running under: Pop!_OS 22.04 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/openblas-pthread/libblas.so.3
# LAPACK: /usr/lib/x86_64-linux-gnu/openblas-pthread/libopenblasp-r0.3.20.so;  LAPACK version 3.10.0
#
# locale:
#  [1] LC_CTYPE=es_ES.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=es_ES.UTF-8        LC_COLLATE=es_ES.UTF-8
#  [5] LC_MONETARY=es_ES.UTF-8    LC_MESSAGES=es_ES.UTF-8
#  [7] LC_PAPER=es_ES.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=es_ES.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Madrid
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] ggcorrplot_0.1.4.1 forcats_0.5.1      stringr_1.4.0      dplyr_1.0.8
#  [5] purrr_1.2.0        readr_2.1.2        tidyr_1.2.0        tibble_3.1.6
#  [9] ggplot2_4.0.0      tidyverse_1.3.1
#
# loaded via a namespace (and not attached):
#  [1] utf8_1.2.2         generics_0.1.2     xml2_1.3.3         stringi_1.7.6
#  [5] hms_1.1.1          digest_0.6.29      magrittr_2.0.2     evaluate_0.15
#  [9] grid_4.5.2         RColorBrewer_1.1-2 pbdZMQ_0.3-14      fastmap_1.2.0
# [13] cellranger_1.1.0   jsonlite_1.7.3     backports_1.4.1    DBI_1.1.2
# [17] rvest_1.0.2        httr_1.4.2         fansi_1.0.2        scales_1.4.0
# [21] modelr_0.1.8       cli_3.6.5          rlang_1.1.6        crayon_1.5.0
# [25] dbplyr_2.1.1       reprex_2.0.1       ellipsis_0.3.2     withr_3.0.2
# [29] base64enc_0.1-3    repr_1.1.7         tools_4.5.2        tzdb_0.2.0
# [33] uuid_1.0-3         broom_0.7.12       assertthat_0.2.1   IRdisplay_1.1
# [37] vctrs_0.6.5        R6_2.5.1           lifecycle_1.0.4    lubridate_1.8.0
# [41] fs_1.5.2           pkgconfig_2.0.3    pillar_1.7.0       gtable_0.3.6
# [45] glue_1.6.1         Rcpp_1.0.8         haven_2.4.3        tidyselect_1.1.2
# [49] rstudioapi_0.13    IRkernel_1.3.2     farver_2.1.0       htmltools_0.5.8.1
# [53] compiler_4.5.2     S7_0.2.0           readxl_1.3.1

# %% [markdown]
# ## 1. Variables y tipos
#
# En R se recomienda usar la **asignación con flecha** `<-`, aunque `=` también funciona. R es **1-indexado**.

# %%
x <- 10          # asignación recomendada
y = 20           # también válido
z <- x + y
z

num <- 3.14
ent <- 10L
logi <- TRUE
cad <- "Hola"
comp <- 3 + 2i

list(
  is_numeric = is.numeric(num),
  is_integer = is.integer(ent),
  is_logical = is.logical(logi),
  is_character = is.character(cad),
  is_complex = is.complex(comp)
)
# Out:
# [1] 30
# $is_numeric
# [1] TRUE
#
# $is_integer
# [1] TRUE
#
# $is_logical
# [1] TRUE
#
# $is_character
# [1] TRUE
#
# $is_complex
# [1] TRUE

# %% [markdown]
# ### Conversión de tipos

# %%
as.numeric("3.14")
as.character(42)
as.logical(0)   # TRUE
# Out:
# [1] 3.14
# [1] "42"
# [1] FALSE

# %% [markdown]
# ## 2. Operadores
#
# **Aritméticos, comparación y lógicos**.

# %%
a <- 10; b <- 3
c(a_plus_b = a + b,
  a_minus_b = a - b,
  a_times_b = a * b,
  a_div_b = a / b,
  a_pow_b = a ^ b,
  a_mod_b = a %% b,
  a_intdiv_b = a %/% b)

x <- 5; y <- 7
c(eq = x == y,
  ne = x != y,
  lt = x < y,
  gt = x > y,
  and_op = (x > 0) & (y > 0),
  or_op = (x > 0) | (y < 0),
  not_true = !TRUE)
# Out:
#    a_plus_b   a_minus_b   a_times_b     a_div_b     a_pow_b     a_mod_b
#   13.000000    7.000000   30.000000    3.333333 1000.000000    1.000000
#  a_intdiv_b
#    3.000000
#       eq       ne       lt       gt   and_op    or_op not_true
#    FALSE     TRUE     TRUE    FALSE     TRUE     TRUE    FALSE

# %% [markdown]
# ## 3. Estructuras de datos
#
# - **Vectores** (homogéneos)
# - **Listas** (heterogéneas)
# - **Matrices**
# - **Data frames** (tabulares)

# %% [markdown]
# ### 3.1 Vectores

# %%
nums <- c(1, 2, 3, 4)
chars <- c("a", "b", "c")
list(
  first = nums[1],      # 1-indexado
  len = length(nums),
  sum = sum(nums),
  mean = mean(nums)
)
# Out:
# $first
# [1] 1
#
# $len
# [1] 4
#
# $sum
# [1] 10
#
# $mean
# [1] 2.5

# %% [markdown]
# ### 3.2 Listas

# %%
persona <- list(nombre = "Ana", edad = 25, notas = c(8, 9, 10))
persona$nombre
persona$notas[2]
# Out:
# [1] "Ana"
# [1] 9

# %% [markdown]
# ### 3.3 Matrices

# %%
m <- matrix(1:9, nrow = 3, ncol = 3)
m
t(m)              # transpuesta
m[1, 2]           # fila 1, columna 2
# Out:
#      [,1] [,2] [,3]
# [1,] 1    4    7
# [2,] 2    5    8
# [3,] 3    6    9
#      [,1] [,2] [,3]
# [1,] 1    2    3
# [2,] 4    5    6
# [3,] 7    8    9
# [1] 4

# %% [markdown]
# ### 3.4 Data frames

# %%
df <- data.frame(
  nombre = c("Ana", "Luis", "Marta"),
  edad = c(20, 22, 19),
  nota = c(8.5, 7.3, 9.1)
)
head(df)
df$edad
mean(df$nota)
# Out:
#   nombre edad nota
# 1 Ana    20   8.5
# 2 Luis   22   7.3
# 3 Marta  19   9.1
# [1] 20 22 19
# [1] 8.3

# %% [markdown]
# ## 4. Control de flujo

# %% [markdown]
# ### 4.1 `if` / `else if` / `else`

# %%
x <- 10
if (x > 0) {
  print("Positivo")
} else if (x == 0) {
  print("Cero")
} else {
  print("Negativo")
}
# Out:
# [1] "Positivo"

# %% [markdown]
# ### 4.2 Bucle `for`

# %%
for (i in 1:5) {
  print(i)
}
# Out:
# [1] 1
# [1] 2
# [1] 3
# [1] 4
# [1] 5

# %% [markdown]
# ### 4.3 Bucle `while`

# %%
i <- 1
while (i <= 5) {
  print(i)
  i <- i + 1
}
# Out:
# [1] 1
# [1] 2
# [1] 3
# [1] 4
# [1] 5

# %% [markdown]
# ### 4.4 Bucle `repeat` (romper con `break`)

# %%
i <- 1
repeat {
  print(i)
  i <- i + 1
  if (i > 5) break
}
# Out:
# [1] 1
# [1] 2
# [1] 3
# [1] 4
# [1] 5

# %% [markdown]
# ## 5. Funciones

# %% [markdown]
# ### 5.1 Definición y retorno

# %%
suma <- function(a, b) {
  return(a + b)
}
a<-4
6 -> b
suma(a=4, b=1)
a
b
# Out:
# [1] 5
# [1] 4
# [1] 6

# %% [markdown]
# ### 5.2 Parámetros por defecto y funciones anónimas

# %%
potencia <- function(base, exp = 2) { base ^ exp }
c(pot_2 = potencia(3), pot_3 = potencia(3, 3))

lapply(1:5, function(x) x^2)
# Out:
# pot_2 pot_3
#     9    27
# [[1]]
# [1] 1
#
# [[2]]
# [1] 4
#
# [[3]]
# [1] 9
#
# [[4]]
# [1] 16
#
# [[5]]
# [1] 25

# %% [markdown]
# ## 6. Funciones predefinidas útiles

# %%
# Matemáticas
nums <- c(2, 4, 6, 8)
c(sum = sum(nums), mean = mean(nums), sd = sd(nums), var = var(nums))
round(3.14159, 2)

# Texto
txt <- "Programar en R es genial"
c(nchar = nchar(txt))
toupper(txt)
tolower(txt)
paste("Hola", "mundo", sep = "-")
substr(txt, 1, 9)
# Out:
#       sum      mean        sd       var
# 20.000000  5.000000  2.581989  6.666667
# [1] 3.14
# nchar
#    24
# [1] "PROGRAMAR EN R ES GENIAL"
# [1] "programar en r es genial"
# [1] "Hola-mundo"
# [1] "Programar"

# %% [markdown]
# ## 7. Lectura y escritura de datos (CSV)

# %%
# Ejemplo (cambiar rutas según tus archivos):
datos <- read.csv("./datasets/flights.csv", sep = ",", header = TRUE)
write.csv(datos, "salida.csv", row.names = FALSE)
cat("Descomenta y ajusta las rutas para probar read.csv()/write.csv().\n")
head(datos)
# Out:
# Descomenta y ajusta las rutas para probar read.csv()/write.csv().
#   year month    passengers
# 1 1949 January  112
# 2 1949 February 118
# 3 1949 March    132
# 4 1949 April    129
# 5 1949 May      121
# 6 1949 June     135

# %% [markdown]
# ## 8. Gráficos básicos

# %%
x <- c(1, 2, 3, 4, 5)
y <- x^2
plot(x, y, type = "b", col = "blue", pch = 19,
     main = "Gráfico base R", xlab = "x", ylab = "y^2")

hist(y, col = "lightblue", main = "Histograma de y^2")

boxplot(y, main = "Boxplot de y^2", col = "orange")
# Out:
# Plot with title “Gráfico base R”
# Plot with title “Histograma de y^2”
# Plot with title “Boxplot de y^2”

# %% [markdown]
# ### 8.1 Gráfico con ggplot2 (estilo EDA)

# %%
dfg <- tibble(x = x, y = y)
ggplot(dfg, aes(x, y)) +
  geom_line() +
  geom_point(size = 3) +
  labs(title = "Prueba ggplot2", x = "x", y = "y^2")
# Out:
# plot without title

# %% [markdown]
# ## 9. (Opcional) Correlaciones rápidas con `ggcorrplot`

# %%
set.seed(123)
demo <- tibble(
  popularity = runif(200, 0, 100),
  danceability = runif(200, 0, 1),
  energy = runif(200, 0, 1),
  valence = runif(200, 0, 1),
  tempo = rnorm(200, 120, 20)
)
M <- cor(demo)
ggcorrplot(M, hc.order = TRUE, type = "lower", lab = TRUE)
# Out:
# Warning message:
# “`aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the ggcorrplot package.
#   Please report the issue at <https://github.com/kassambara/ggcorrplot/issues>.”
# plot without title

# %% [markdown]
# ## 10. Comparativa rápida Python vs R
#
# | Concepto | Python | R |
# |---|---|---|
# | Asignación | `x = 3` | `x <- 3` |
# | Imprimir | `print(x)` | `print(x)` |
# | Tipo | `type(x)` | `class(x)` |
# | Lista | `[1, 2, 3]` | `c(1, 2, 3)` |
# | Índices | 0-based | 1-based |
# | Longitud | `len(x)` | `length(x)` |
# | Suma de vector | `sum(x)` | `sum(x)` |
# | Bucle | `for i in range(5):` | `for (i in 1:5) {}` |
# | Función | `def f(x):` | `f <- function(x) {}` |
# | DataFrame | `pd.DataFrame()` | `data.frame()` |
