# %% [markdown]
# # NLP Fase 2 — Embeddings + LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Dataset

# %%
texts = [
    'me encanta este curso',
    'odio este producto',
    'me gusta bastante',
    'no me gusta nada'
]
labels = [1,0,1,0]
df = pd.DataFrame({'text':texts,'label':labels})
df
# Out:
#                     text  label
# 0  me encanta este curso      1
# 1     odio este producto      0
# 2      me gusta bastante      1
# 3       no me gusta nada      0

# %% [markdown]
# ## TF-IDF baseline

# %%
tfidf = TfidfVectorizer()
X = tfidf.fit_transform(df['text'])
model = LogisticRegression()
model.fit(X, df['label'])
model.predict(X)
# Out:
# array([1, 0, 1, 0])

# %% [markdown]
# ## LSTM

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['text'])
seq = tokenizer.texts_to_sequences(df['text'])
padded = pad_sequences(seq)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(1000, 16),
    tf.keras.layers.LSTM(32),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(padded, df['label'], epochs=5)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.7500 - loss: 0.6908
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7500 - loss: 0.6900
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7500 - loss: 0.6892
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7500 - loss: 0.6884
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.6876

# %% [markdown]
# ## Ejercicios

# %%
# TODO: cambia el tamaño del embedding
# TODO: añade dropout
# TODO: compara resultados
