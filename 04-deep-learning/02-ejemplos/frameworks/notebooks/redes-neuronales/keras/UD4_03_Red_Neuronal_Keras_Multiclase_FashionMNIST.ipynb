# %% [markdown]
# # UD4 — Redes Neuronales con Keras
# ## Clasificación multiclase: **Fashion-MNIST completo**
#
# En este notebook resolvemos el problema **multiclase original** de Fashion-MNIST.
#
# ### Objetivo
# - Clasificar cada imagen en una de las **10 clases** disponibles.
# - Comparar este caso con los problemas binarios anteriores.
#
# ### Qué cambia respecto al caso binario
# - La salida tiene **10 neuronas**
# - Usamos **softmax**
# - Usamos **categorical crossentropy**

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## 1. Carga del dataset

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %% [markdown]
# ## 2. Exploración visual

# %%
class_names = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

plt.figure(figsize=(8, 8))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(x_train[i], cmap="gray")
    plt.title(class_names[y_train[i]])
    plt.axis("off")
plt.show()

# %% [markdown]
# ## 3. Preprocesado
#
# - Normalización
# - Aplanado
# - Codificación one-hot de las etiquetas

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 28 * 28)
x_test = x_test.reshape(-1, 28 * 28)

y_train_cat = keras.utils.to_categorical(y_train, 10)
y_test_cat = keras.utils.to_categorical(y_test, 10)

# %% [markdown]
# ## 4. Definición del modelo
#
# Ahora la capa de salida tiene **10 neuronas** con **softmax**.

# %%
model = keras.Sequential([
    layers.Dense(128, activation="relu", input_shape=(784,)),
    layers.Dense(64, activation="relu"),
    layers.Dense(10, activation="softmax")
])

model.summary()

# %% [markdown]
# ## 5. Compilación

# %%
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# ## 6. Entrenamiento

# %%
history = model.fit(
    x_train,
    y_train_cat,
    epochs=15,
    batch_size=128,
    validation_split=0.2
)

# %% [markdown]
# ## 7. Evaluación

# %%
model.evaluate(x_test, y_test_cat)

# %% [markdown]
# ## 8. Curvas de entrenamiento

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="Train")
plt.plot(history.history["val_loss"], label="Validation")
plt.title("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label="Train")
plt.plot(history.history["val_accuracy"], label="Validation")
plt.title("Accuracy")
plt.legend()

plt.show()

# %% [markdown]
# ## 9. Matriz de confusión

# %%
y_pred = model.predict(x_test).argmax(axis=1)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=class_names)
disp.plot(xticks_rotation=45)
plt.show()

# %% [markdown]
# ## 10. Conclusiones
#
# - El problema multiclase es más complejo
# - Algunas clases se confunden más que otras
# - La función de pérdida y la activación son **clave**
# - El mismo dataset puede generar problemas muy distintos
#
# En el siguiente bloque implementaremos **el mismo modelo en PyTorch**.
