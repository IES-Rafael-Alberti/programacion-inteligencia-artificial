# %%
# Librerías principales
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12,6)

# %% [markdown]
# ## Cargar dataset (California Housing)

# %%
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing(as_frame=True)
df = data.frame.copy()
# target tiene nombre 'MedHouseVal' en este fetch
df.rename(columns={data.target_names[0]: 'MedHouseVal'}, inplace=True)
print('Shape:', df.shape)
df.head()

# %% [markdown]
# ## Información básica y nulos

# %%
print('Descripción rápida:')
print(df.info())
print('
Nulos por columna:')
print(df.isnull().sum())
print('
Estadísticas resumen:')
print(df.describe().T)
: 
,
: {
: 

: [

: 
,
: {
: 

: [
,
,
