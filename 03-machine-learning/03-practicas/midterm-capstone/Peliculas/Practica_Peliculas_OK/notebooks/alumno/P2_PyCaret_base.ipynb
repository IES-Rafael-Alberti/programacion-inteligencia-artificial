# %% [markdown]
# # Práctica 2 — Modelado exploratorio con PyCaret

# %%
import pandas as pd
from pycaret.classification import *

# %%
df = pd.read_csv('movies.csv')

# %% [markdown]
# ## Definición del problema

# %% [markdown]
# Indica clasificación o regresión y justifica.

# %% [markdown]
# ## Setup

# %%
# setup(df, target='rating_high', session_id=42)

# %% [markdown]
# ## Comparación

# %%
# compare_models()

# %% [markdown]
# ## Elección

# %% [markdown]
# Justifica el modelo elegido.

# %% [markdown]
# ## Anexo GPU (opcional)

# %%
# from cuml.linear_model import LogisticRegression
